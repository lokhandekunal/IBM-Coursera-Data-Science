# %% [markdown]
# <h1><center>Applied Data Science Capstone</center></h1>
# <hr>
# <h2><center> IBM Coursera Data Science</center></h2>
# <center><i>by Kunal Lokhande<center>
# <hr>

# %%
import numpy as np 
import pandas as pd

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
